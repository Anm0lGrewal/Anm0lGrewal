.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://www.baylorbarbee.com/wp-content/uploads/2016/09/bg_road2.jpg
# [!] Issue getting: https://www.baylorbarbee.com/wp-content/uploads/2016/09/bg_road2.jpg
# [!] Error:: Remote end closed connection without response
# [%] Downloading Image #15 from https://images.unsplash.com/photo-1542242476-5a3565835a38?ixlib=rb-1.2.1&amp;ixid=eyJhcHBfaWQiOjEyMDd9&amp;w=1000&amp;q=80
# [%] File Downloaded !
#
# [%] Downloading Image #16 from http://pas-wordpress-media.s3.amazonaws.com/content/uploads/2016/07/Road-along-the-sunset.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://www.thenology.com/wp-content/uploads/2016/04/sunset-road-wallpaper.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://images3.alphacoders.com/228/22857.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from http://www.baltana.com/files/wallpapers-2/Road-Background-Wallpaper-03559.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://cdn.fodors.com/wp-content/uploads/2017/09/Road-Trips-Cabot-Trail.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Evacuated_Highway_401_Color.jpg/1200px-Evacuated_Highway_401_Color.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://wallup.net/wp-content/uploads/2016/01/207938-landscape-road.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://2.bp.blogspot.com/_t3qaNX-CFyA/SI4DsXMoEBI/AAAAAAAAAVo/kfDaMOXTORA/s1600/road
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://3.bp.blogspot.com/_o3upKVaFSeQ/TNcJ8P4FJnI/AAAAAAAAAKA/9OvgGT0aZn0/s1600/northern-road.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://images5.alphacoders.com/567/thumb-1920-567118.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from http://ww1.prweb.com/prfiles/2013/04/22/10660607/road.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://pixnio.com/free-images/2017/05/07/2017-05-07-13-55-09.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from http://oscar.ofm.co.za/img/a1__2012101816495133u80.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #29 from http://www.trbimg.com/img-576d94af/turbine/la-tr-roadtrips-20160626
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://www.chill.ie/images/road-empty.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 30 images.

# %%
# Preprocessing part
import os
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.transform import resize

# %%
target = []
images = []
flat_data = []

DATADIR = '/content/images'
CATEGORIES = ['Grass','Stone','road']

for category in CATEGORIES:
  class_num = CATEGORIES.index(category)
  path = os.path.join(DATADIR,category)
  for img in os.listdir(path):
    img_array = imread(os.path.join(path,img))
    #plt.imshow(img_array)
    img_resized = resize(img_array,(150,150,3))
    flat_data.append(img_resized.flatten())
    images.append(img_resized)
    target.append(class_num)
flat_data = np.array(flat_data)
target = np.array(target)
images = np.array(images)

# %%
#split data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(flat_data,target,test_size = 0.3, random_state = 42)

# %%
#Classification algorithm
#We will be using SVM supervised learning algorithm
from sklearn.model_selection import GridSearchCV
from sklearn import svm
param_grid = [
              {'C':[1,10,100,1000],'kernel':['linear']},
              {'C':[1,10,100,1000],'gamma':[0.001,0.0001] ,'kernel':['rbf']}
]

svc = svm.SVC( probability = True )
clf = GridSearchCV(svc,param_grid)
clf.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(probability=True),
#              param_grid=[{'C': [1, 10, 100, 1000], 'kernel': ['linear']},
#                          {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001],
#                           'kernel': ['rbf']}])

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9259259259259259

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[7, 0, 0],
#        [1, 9, 0],
#        [1, 0, 9]])

# %%
import pickle
pickle.dump(clf,open('img_model.p','wb'))

# %%
model = pickle.load(open('img_model.p','rb'))

# %%
#Testing a brand new image
flat_data = []
url = input('Enter your URL')
img = imread(url)
img_resized = resize(img,(150,150,3))
flat_data.append(img_resized.flatten())
flat_data = np.array(flat_data)
print(img.shape)
plt.imshow(img_resized)
y_out = model.predict(flat_data)
y_out = CATEGORIES[y_out[0]]
if(y_out != "road"):
  print(f'PREDICTED OUTPUT: {y_out} Mountain')
else:
  print(f'PREDICTED OUTPUT: {y_out}')
# Out:
# Enter your URLhttps://images.unsplash.com/photo-1589496933738-f5c27bc146e3?auto=format&fit=crop&q=80&w=2787&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D
# (4181, 2787, 3)
# PREDICTED OUTPUT: Grass Mountain
